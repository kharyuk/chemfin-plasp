# %% [markdown]
# # Autoencoder approach: predict part of plant

# %% [markdown]
# ## Contents
# - [1. Imports](#Imports)
# - [2. Build models](#Build-models)
# - [3. Approximation error](#Approximation-error)
# - [4. Encode data with computed autoencoders](#Encode-data-with-computed-autoencoders)
# - [5. Logistic regression classifier with encoded data](#Logistic-regression-classifier-with-encoded-data)
# - [6. Gaussian Naive Bayes classifier with encoded data](#Gaussian-Naive-Bayes-classifier-with-encoded-data)
# - [7. Hybrid Bayesian classifier with bnlearn](#Hybrid-Bayesian-classifier-with-bnlearn)
#
#
#
# [Back to Chemfin](../Chemfin.ipynb)

# %% [markdown]
# ### Imports
# The first cell with code includes all necessary inputs.
#
# Requires [numpy](http://www.numpy.org/), [scikit-learn](http://scikit-learn.org/), [pyTorch](http://pytorch.org/), [Rpy2](https://rpy2.readthedocs.io).
#
# [Back to contents](#Contents)

# %%
import sys
sys.path.append('../src/')
import copy

import numpy as np
import os
import torch
from torch import nn
from torch.autograd import Variable
from torch.utils.data import DataLoader

import autoencoder as ae

random_state = 150
torch.manual_seed(random_state);


from computational_utils import reshape
import bayesian_networks as bn

from io_work import stringSplitByNumbers

import time
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, f1_score

from computational_utils import reshape
from sklearn.metrics import confusion_matrix
from sklearn.naive_bayes import GaussianNB

# %% [markdown]
# ### Build models
#
# Next cell contains script to build autoencoder models relevant to CV indexes supplied by data/cv_indices.npz.
#
# Parameters to control are:
#
# - sizes: list of integers which specifies output sizes for each encoding layer
# - batch_size: number of samples to be used for computing new update at each epoch
# - nEpoch: number of epochs for each layer
# - num_workers: number of parallel processes to work
#
# [Back to contents](#Contents)

# %%
data_dirname = '../data/'
model_dirname = '../models/autoencoder/'
filename_dataset = 'dataset_parts.npz'
filename_cv = 'cv_indices_parts.npz'

model_filename_prefix = 'parts_model_ae_'

df = np.load(data_dirname+filename_dataset)
T, labels = df['data'], df['label']
# unfold into matrix
T = reshape(T, [T.shape[0], -1])
# normalize among samples
T /= np.linalg.norm(T, axis=1, keepdims=1)
print 'full'
    
sizes = [400, 100, 25]
nEpoch = [1000, 1000, 1000]
batch_size = 200
num_workers = 4

df = np.load(data_dirname+filename_cv)
test_indices, train_indices = df['test_indices'], df['train_indices']



ae.buildAutoencoderModels(
    T, train_indices, test_indices, sizes, model_dirname, nEpoch,
    batch_size, num_workers, model_filename_prefix
)
# Out:
# full
# ============= CV 1 / 25 ================
# (1) Errors on training set (1808 samples):
# min=8.201e-02 / mean=1.370e-01 / median=1.327e-01 / max=2.933e-01
# (1) Errors on validation set (455 samples):
# min=9.331e-02 / mean=1.672e-01 / median=1.511e-01 / max=6.083e-01
# (2) Errors on training set (1808 samples):
# min=4.771e-02 / mean=1.003e-01 / median=9.730e-02 / max=2.104e-01
# (2) Errors on validation set (455 samples):
# min=6.020e-02 / mean=1.401e-01 / median=1.190e-01 / max=6.083e-01
# (3) Errors on training set (1808 samples):
# min=6.476e-02 / mean=1.175e-01 / median=1.138e-01 / max=3.463e-01
# (3) Errors on validation set (455 samples):
# min=6.751e-02 / mean=1.653e-01 / median=1.409e-01 / max=7.377e-01
# ============= CV 2 / 25 ================
# (1) Errors on training set (1808 samples):
# min=7.969e-02 / mean=1.371e-01 / median=1.323e-01 / max=2.867e-01
# (1) Errors on validation set (455 samples):
# min=7.995e-02 / mean=1.636e-01 / median=1.473e-01 / max=6.735e-01
# (2) Errors on training set (1808 samples):
# min=4.471e-02 / mean=9.607e-02 / median=9.325e-02 / max=2.108e-01
# (2) Errors on validation set (455 samples):
# min=4.736e-02 / mean=1.329e-01 / median=1.133e-01 / max=8.102e-01
# (3) Errors on training set (1808 samples):
# min=5.648e-02 / mean=1.194e-01 / median=1.150e-01 / max=3.823e-01
# (3) Errors on validation set (455 samples):
# min=6.346e-02 / mean=1.610e-01 / median=1.397e-01 / max=7.166e-01
# ============= CV 3 / 25 ================
# (1) Errors on training set (1810 samples):
# min=7.899e-02 / mean=1.388e-01 / median=1.347e-01 / max=2.803e-01
# (1) Errors on validation set (453 samples):
# min=8.574e-02 / mean=1.722e-01 / median=1.571e-01 / max=5.819e-01
# (2) Errors on training set (1810 samples):
# min=4.606e-02 / mean=9.767e-02 / median=9.559e-02 / max=2.503e-01
# (2) Errors on validation set (453 samples):
# min=5.527e-02 / mean=1.401e-01 / median=1.181e-01 / max=6.057e-01
# (3) Errors on training set (1810 samples):
# min=5.361e-02 / mean=1.139e-01 / median=1.106e-01 / max=2.530e-01
# (3) Errors on validation set (453 samples):
# min=6.138e-02 / mean=1.661e-01 / median=1.425e-01 / max=7.399e-01
# ============= CV 4 / 25 ================
# (1) Errors on training set (1813 samples):
# min=8.286e-02 / mean=1.391e-01 / median=1.342e-01 / max=3.311e-01
# (1) Errors on validation set (450 samples):
# min=8.506e-02 / mean=1.606e-01 / median=1.495e-01 / max=4.630e-01
# (2) Errors on training set (1813 samples):
# min=5.259e-02 / mean=1.041e-01 / median=1.011e-01 / max=2.193e-01
# (2) Errors on validation set (450 samples):
# min=6.026e-02 / mean=1.332e-01 / median=1.168e-01 / max=3.768e-01
# (3) Errors on training set (1813 samples):
# min=5.182e-02 / mean=1.199e-01 / median=1.171e-01 / max=3.524e-01
# (3) Errors on validation set (450 samples):
# min=6.050e-02 / mean=1.569e-01 / median=1.390e-01 / max=5.099e-01
# ============= CV 5 / 25 ================
# (1) Errors on training set (1813 samples):
# min=8.267e-02 / mean=1.410e-01 / median=1.364e-01 / max=3.439e-01
# (1) Errors on validation set (450 samples):
# min=8.812e-02 / mean=1.665e-01 / median=1.498e-01 / max=5.442e-01
# (2) Errors on training set (1813 samples):
# min=4.860e-02 / mean=9.726e-02 / median=9.535e-02 / max=2.136e-01
# (2) Errors on validation set (450 samples):
# min=4.798e-02 / mean=1.355e-01 / median=1.125e-01 / max=7.606e-01
# (3) Errors on training set (1813 samples):
# min=5.574e-02 / mean=1.128e-01 / median=1.094e-01 / max=3.475e-01
# (3) Errors on validation set (450 samples):
# min=6.079e-02 / mean=1.572e-01 / median=1.322e-01 / max=7.903e-01
# ============= CV 6 / 25 ================
# (1) Errors on training set (1808 samples):
# min=7.530e-02 / mean=1.349e-01 / median=1.307e-01 / max=3.162e-01
# (1) Errors on validation set (455 samples):
# min=7.758e-02 / mean=1.673e-01 / median=1.472e-01 / max=7.076e-01
# (2) Errors on training set (1808 samples):
# min=5.284e-02 / mean=1.056e-01 / median=1.031e-01 / max=2.151e-01
# (2) Errors on validation set (455 samples):
# min=6.542e-02 / mean=1.493e-01 / median=1.277e-01 / max=8.888e-01
# (3) Errors on training set (1808 samples):
# min=4.663e-02 / mean=1.153e-01 / median=1.118e-01 / max=3.436e-01
# (3) Errors on validation set (455 samples):
# min=6.843e-02 / mean=1.677e-01 / median=1.405e-01 / max=7.614e-01
# ============= CV 7 / 25 ================
# (1) Errors on training set (1808 samples):
# min=7.870e-02 / mean=1.402e-01 / median=1.359e-01 / max=2.876e-01
# (1) Errors on validation set (455 samples):
# min=8.688e-02 / mean=1.675e-01 / median=1.528e-01 / max=4.695e-01
# (2) Errors on training set (1808 samples):
# min=5.137e-02 / mean=1.001e-01 / median=9.732e-02 / max=2.198e-01
# (2) Errors on validation set (455 samples):
# min=5.959e-02 / mean=1.357e-01 / median=1.160e-01 / max=4.382e-01
# (3) Errors on training set (1808 samples):
# min=5.515e-02 / mean=1.149e-01 / median=1.124e-01 / max=2.478e-01
# (3) Errors on validation set (455 samples):
# min=6.265e-02 / mean=1.583e-01 / median=1.399e-01 / max=5.782e-01
# ============= CV 8 / 25 ================
# (1) Errors on training set (1810 samples):
# min=7.263e-02 / mean=1.381e-01 / median=1.355e-01 / max=2.629e-01
# (1) Errors on validation set (453 samples):
# min=7.492e-02 / mean=1.696e-01 / median=1.568e-01 / max=5.917e-01
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-10-63bce1814f6d> in <module>()
#      26 ae.buildAutoencoderModels(
#      27     T, train_indices, test_indices, sizes, model_dirname, nEpoch,
# ---> 28     batch_size, num_workers, model_filename_prefix
#      29 )
#
# /home/pavel/work/chemfin-plasp/src/autoencoder.py in buildAutoencoderModels(T, train_indices, test_indices, sizes_in, dirname, nEpoch, batch_size, num_workers, model_filename_prefix)
#     202                     autoencoder.Decoder[2*(i+1)].bias = biases[2*i+1]
#     203             t1_time = time.time(); t1_clock = time.clock()
# --> 204             loss_values_level = autoencoder.fit(data, nEpoch[k], verbose=0)
#     205             t2_clock = time.clock(); t2_time = time.time()
#     206             times[k_cv, k, 0] = t2_time-t1_time
#
# /home/pavel/work/chemfin-plasp/src/autoencoder.py in fit(self, X, nEpoch, delta, verbose)
#     142         loss_values = []
#     143         for epoch in xrange(nEpoch):
# --> 144             for partX in X:
#     145                 var = Variable(partX)
#     146                 var.cpu()
#
# /home/pavel/apd/lib/python2.7/site-packages/torch/utils/data/dataloader.pyc in __next__(self)
#     273         while True:
#     274             assert (not self.shutdown and self.batches_outstanding > 0)
# --> 275             idx, batch = self._get_batch()
#     276             self.batches_outstanding -= 1
#     277             if idx != self.rcvd_idx:
#
# /home/pavel/apd/lib/python2.7/site-packages/torch/utils/data/dataloader.pyc in _get_batch(self)
#     252                 raise RuntimeError('DataLoader timed out after {} seconds'.format(self.timeout))
#     253         else:
# --> 254             return self.data_queue.get()
#     255
#     256     def __next__(self):
#
# /home/pavel/apd/lib/python2.7/multiprocessing/queues.pyc in get()
#     374             racquire()
#     375             try:
# --> 376                 return recv()
#     377             finally:
#     378                 rrelease()
#
# /home/pavel/apd/lib/python2.7/site-packages/torch/multiprocessing/queue.pyc in recv(self)
#      20     def recv(self):
#      21         buf = self.recv_bytes()
# ---> 22         return pickle.loads(buf)
#      23
#      24     def __getattr__(self, name):
#
# /home/pavel/apd/lib/python2.7/pickle.pyc in loads(str)
#    1386 def loads(str):
#    1387     file = StringIO(str)
# -> 1388     return Unpickler(file).load()
#    1389
#    1390 # Doctest
#
# /home/pavel/apd/lib/python2.7/pickle.pyc in load(self)
#     862             while 1:
#     863                 key = read(1)
# --> 864                 dispatch[key](self)
#     865         except _Stop, stopinst:
#     866             return stopinst.value
#
# /home/pavel/apd/lib/python2.7/pickle.pyc in load_reduce(self)
#    1137         args = stack.pop()
#    1138         func = stack[-1]
# -> 1139         value = func(*args)
#    1140         stack[-1] = value
#    1141     dispatch[REDUCE] = load_reduce
#
# /home/pavel/apd/lib/python2.7/site-packages/torch/multiprocessing/reductions.pyc in rebuild_storage_fd(cls, df, size)
#      66 def rebuild_storage_fd(cls, df, size):
#      67     if sys.version_info[0] == 2:
# ---> 68         fd = multiprocessing.reduction.rebuild_handle(df)
#      69     else:
#      70         fd = df.detach()
#
# /home/pavel/apd/lib/python2.7/multiprocessing/reduction.pyc in rebuild_handle(pickled_data)
#     155     conn = Client(address, authkey=current_process().authkey)
#     156     conn.send((handle, os.getpid()))
# --> 157     new_handle = recv_handle(conn)
#     158     conn.close()
#     159     return new_handle
#
# /home/pavel/apd/lib/python2.7/multiprocessing/reduction.pyc in recv_handle(conn)
#      81
#      82     def recv_handle(conn):
# ---> 83         return _multiprocessing.recvfd(conn.fileno())
#      84
#      85 #
#
# OSError: [Errno 4] Interrupted system call

# %%
data_dirname = '../data/'
model_dirname = '../models/autoencoder/'
filename_dataset = 'dataset_parts_3.npz'
filename_cv = 'cv_indices_parts_3.npz'

model_filename_prefix = 'parts3_model_ae_'

df = np.load(data_dirname+filename_dataset)
T, labels = df['data'], df['label']
# unfold into matrix
T = reshape(T, [T.shape[0], -1])
# normalize among samples
T /= np.linalg.norm(T, axis=1, keepdims=1)
print 'full'
    
sizes = [400, 100, 25]
nEpoch = [1000, 1000, 1000]
batch_size = 200
num_workers = 4

df = np.load(data_dirname+filename_cv)
test_indices, train_indices = df['test_indices'], df['train_indices']



ae.buildAutoencoderModels(
    T, train_indices[:5], test_indices[:5], sizes, model_dirname, nEpoch,
    batch_size, num_workers, model_filename_prefix
)
# Out:
# full
# ============= CV 1 / 5 ================
# (1) Errors on training set (1809 samples):
# min=7.838e-02 / mean=1.364e-01 / median=1.327e-01 / max=2.908e-01
# (1) Errors on validation set (454 samples):
# min=8.157e-02 / mean=1.702e-01 / median=1.514e-01 / max=6.846e-01
# (2) Errors on training set (1809 samples):
# min=4.770e-02 / mean=1.009e-01 / median=9.897e-02 / max=2.056e-01
# (2) Errors on validation set (454 samples):
# min=4.926e-02 / mean=1.443e-01 / median=1.213e-01 / max=6.839e-01
# (3) Errors on training set (1809 samples):
# min=5.766e-02 / mean=1.206e-01 / median=1.172e-01 / max=2.390e-01
# (3) Errors on validation set (454 samples):
# min=5.973e-02 / mean=1.743e-01 / median=1.455e-01 / max=7.904e-01
# ============= CV 2 / 5 ================
# (1) Errors on training set (1809 samples):
# min=7.348e-02 / mean=1.373e-01 / median=1.325e-01 / max=3.088e-01
# (1) Errors on validation set (454 samples):
# min=9.019e-02 / mean=1.651e-01 / median=1.476e-01 / max=5.086e-01
# (2) Errors on training set (1809 samples):
# min=4.428e-02 / mean=1.046e-01 / median=1.024e-01 / max=2.211e-01
# (2) Errors on validation set (454 samples):
# min=4.844e-02 / mean=1.402e-01 / median=1.203e-01 / max=4.700e-01
# (3) Errors on training set (1809 samples):
# min=5.272e-02 / mean=1.165e-01 / median=1.131e-01 / max=3.382e-01
# (3) Errors on validation set (454 samples):
# min=5.646e-02 / mean=1.615e-01 / median=1.368e-01 / max=6.627e-01
# ============= CV 3 / 5 ================
# (1) Errors on training set (1810 samples):
# min=7.226e-02 / mean=1.379e-01 / median=1.332e-01 / max=2.930e-01
# (1) Errors on validation set (453 samples):
# min=7.564e-02 / mean=1.589e-01 / median=1.454e-01 / max=4.684e-01
# Process Process-145415:
# Process Process-145413:
# Process Process-145414:
# Process Process-145416:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/pavel/apd/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#   File "/home/pavel/apd/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#   File "/home/pavel/apd/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#     self.run()
#     self.run()
#     self.run()
#   File "/home/pavel/apd/lib/python2.7/multiprocessing/process.py", line 114, in run
# Traceback (most recent call last):
#     self._target(*self._args, **self._kwargs)
#   File "/home/pavel/apd/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/home/pavel/apd/lib/python2.7/site-packages/torch/multiprocessing/queue.py", line 21, in recv
#   File "/home/pavel/apd/lib/python2.7/site-packages/torch/utils/data/dataloader.py", line 50, in _worker_loop
#     r = index_queue.get()
#     self._target(*self._args, **self._kwargs)
#   File "/home/pavel/apd/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#     self.run()
#   File "/home/pavel/apd/lib/python2.7/site-packages/torch/utils/data/dataloader.py", line 50, in _worker_loop
#   File "/home/pavel/apd/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/pavel/apd/lib/python2.7/site-packages/torch/utils/data/dataloader.py", line 50, in _worker_loop
#     r = index_queue.get()
#   File "/home/pavel/apd/lib/python2.7/multiprocessing/queues.py", line 374, in get
#   File "/home/pavel/apd/lib/python2.7/multiprocessing/queues.py", line 374, in get
#   File "/home/pavel/apd/lib/python2.7/multiprocessing/process.py", line 114, in run
#     racquire()
# KeyboardInterrupt
#     self._target(*self._args, **self._kwargs)
#     racquire()
# KeyboardInterrupt
#     r = index_queue.get()
#   File "/home/pavel/apd/lib/python2.7/site-packages/torch/utils/data/dataloader.py", line 50, in _worker_loop
#   File "/home/pavel/apd/lib/python2.7/multiprocessing/queues.py", line 374, in get
#     racquire()
# KeyboardInterrupt
#     r = index_queue.get()
#   File "/home/pavel/apd/lib/python2.7/multiprocessing/queues.py", line 376, in get
#     return recv()
#     buf = self.recv_bytes()
# KeyboardInterrupt
# Exception socket.error: error(2, 'No such file or directory') in <bound method DataLoaderIter.__del__ of <torch.utils.data.dataloader.DataLoaderIter object at 0x7fc5a685eb10>> ignored
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-c92f58cbf808> in <module>()
#      26 ae.buildAutoencoderModels(
#      27     T, train_indices[:5], test_indices[:5], sizes, model_dirname, nEpoch,
# ---> 28     batch_size, num_workers, model_filename_prefix
#      29 )
#
# /home/pavel/work/chemfin-plasp/src/autoencoder.py in buildAutoencoderModels(T, train_indices, test_indices, sizes_in, dirname, nEpoch, batch_size, num_workers, model_filename_prefix)
#     202                     autoencoder.Decoder[2*(i+1)].bias = biases[2*i+1]
#     203             t1_time = time.time(); t1_clock = time.clock()
# --> 204             loss_values_level = autoencoder.fit(data, nEpoch[k], verbose=0)
#     205             t2_clock = time.clock(); t2_time = time.time()
#     206             times[k_cv, k, 0] = t2_time-t1_time
#
# /home/pavel/work/chemfin-plasp/src/autoencoder.py in fit(self, X, nEpoch, delta, verbose)
#     155                     loss_val[0] = (loss.data.numpy())[0]
#     156                     return loss
# --> 157                 optimizer.step(closure)
#     158             #print loss.data
#     159             if verbose:
#
# /home/pavel/apd/lib/python2.7/site-packages/torch/optim/adam.pyc in step(self, closure)
#      38         loss = None
#      39         if closure is not None:
# ---> 40             loss = closure()
#      41
#      42         for group in self.param_groups:
#
# /home/pavel/work/chemfin-plasp/src/autoencoder.py in closure(loss_val)
#     150                 def closure(loss_val=loss_val):
#     151                     optimizer.zero_grad()
# --> 152                     output = self(var)
#     153                     loss = lossFunction(output, var)
#     154                     loss.backward()
#
# /home/pavel/apd/lib/python2.7/site-packages/torch/nn/modules/module.pyc in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# /home/pavel/work/chemfin-plasp/src/autoencoder.py in forward(self, X)
#     131
#     132     def forward(self, X):
# --> 133         Y = self.encode(X)
#     134         Z = self.decode(Y)
#     135         return Z
#
# /home/pavel/work/chemfin-plasp/src/autoencoder.py in encode(self, X)
#     125
#     126     def encode(self, X):
# --> 127         return self.Encoder(X)
#     128
#     129     def decode(self, Y):
#
# /home/pavel/apd/lib/python2.7/site-packages/torch/nn/modules/module.pyc in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# /home/pavel/apd/lib/python2.7/site-packages/torch/nn/modules/container.pyc in forward(self, input)
#      65     def forward(self, input):
#      66         for module in self._modules.values():
# ---> 67             input = module(input)
#      68         return input
#      69
#
# /home/pavel/apd/lib/python2.7/site-packages/torch/nn/modules/module.pyc in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# /home/pavel/apd/lib/python2.7/site-packages/torch/nn/modules/linear.pyc in forward(self, input)
#      53
#      54     def forward(self, input):
# ---> 55         return F.linear(input, self.weight, self.bias)
#      56
#      57     def __repr__(self):
#
# /home/pavel/apd/lib/python2.7/site-packages/torch/nn/functional.pyc in linear(input, weight, bias)
#     833     if input.dim() == 2 and bias is not None:
#     834         # fused op is marginally faster
# --> 835         return torch.addmm(bias, input, weight.t())
#     836
#     837     output = input.matmul(weight.t())
#
# KeyboardInterrupt:

# %%
data_dirname = '../data/'
dirname_results = '../results/'
filename_results = 'autoencoder+LR_parts'
data_filename = 'autoencoded_dataset_parts.npz'
data_test2_filename = 'autoencoded_test2.npz'

filename_cv = 'cv_indices.npz'
df = np.load(data_dirname+filename_cv)
test_indices, train_indices = df['test_indices'], df['train_indices']

df = np.load(data_dirname+data_test2_filename)
X_test2, y_test2 = df['data'], df['label']
y_test2 = reshape(y_test2, [-1, 1])

df = np.load(data_dirname+data_filename)
X, y = df['data'], df['label']
y = reshape(y, [-1, 1])
colnames = ['identity'] + ['V%d' % (i) for i in xrange(X.shape[-1])]

tms = []
predict_train_all = []
predict_test_all = []
predict_test2_all = []

confusion_matrices = []
accuracies = []
f1s = []

# correct label in the end
predicted_probas_test = []
predicted_probas_test2 = []
for k in xrange(len(train_indices)):
    print "CV %d / %d" % (k+1, len(train_indices))
    train_index = train_indices[k]
    test_index = test_indices[k]
    
    classifier = LogisticRegression(
        penalty='l1', dual=False, tol=0.0001, C=1000.0, fit_intercept=True,
        intercept_scaling=1, class_weight=None, random_state=None,
        solver='saga', max_iter=1000, multi_class='multinomial', verbose=0,
        warm_start=False, n_jobs=1
    )
    
    tic = time.clock();
    classifier.fit(X[k][train_index], y[train_index])
    toc = time.clock();
    
    tms_loc = [toc-tic]
    
    tic = time.clock()
    predict_train = classifier.predict(X[k][train_index])
    toc = time.clock()
    tms_loc.append(toc-tic)
    acc_loc = [accuracy_score(y[train_index], predict_train)]
    f1_loc = [f1_score(y[train_index], predict_train, average='weighted')]
    tic = time.clock()
    predict_test = classifier.predict(X[k][test_index])
    toc = time.clock()
    acc_loc.append( accuracy_score(y[test_index], predict_test) )
    f1_loc.append(f1_score(y[test_index], predict_test, average='weighted') )
    confusion_matrices.append(confusion_matrix(y[test_index], predict_test))
    tms_loc.append(toc-tic)
    
    tmp = reshape(np.array(y[test_index]), [-1, 1])
    tmp = np.hstack([classifier.predict_proba(X[k][test_index]), tmp])
    predicted_probas_test.append( tmp.copy() )
    tmp = reshape(np.array(y_test2), [-1, 1])
    tmp = np.hstack([classifier.predict_proba(X_test2[k]), tmp])
    predicted_probas_test2.append( tmp.copy() )
    
    predict_test2 = classifier.predict(X_test2[k])
    acc_loc.append( accuracy_score(y_test2, predict_test2) )
    f1_loc.append(f1_score(y_test2, predict_test2, average='weighted') )
    
    accuracies.append(acc_loc)
    f1s.append(f1_loc)
    tms.append(tms_loc)
    predict_train_all.append( predict_train )
    predict_test_all.append( predict_test )
    predict_test2_all.append( predict_test2 )
    np.savez_compressed(
        dirname_results+filename_results, tms=tms, predict_train=predict_train_all,
        predict_test=predict_test_all, predict_test2=predict_test2_all, test_indices=test_indices,
        train_indices=train_indices, y_test2=y_test2.T, y=y, confusion_matrices=confusion_matrices,
        acc=accuracies, f1=f1s, predicted_probas_test=predicted_probas_test,
        predicted_probas_test2=predicted_probas_test2
    )
accuracies = np.array(accuracies)
f1s = np.array(f1s)
print "accuracies"
print np.median(accuracies, axis=0)
print "f1 measure"
print np.median(f1s, axis=0)
